# %%
import torch
import torch.nn as nn

# %%
# Input
torch.manual_seed(42)
inputs = torch.tensor([1.0, 2.0, 3.0])

# %%
# Neuron
neuron = nn.Linear(in_features=3, out_features=1)

output = neuron(inputs)
print(output)
# Out:
# tensor([1.5244], grad_fn=<ViewBackward0>)

# %%
# Verify (using formula)
print("Output: ", neuron.weight @ inputs + neuron.bias)
print("Bias: ", neuron.bias[0])
# Out:
# Output:  tensor([1.5244], grad_fn=<AddBackward0>)
# Bias:  tensor(0.5304, grad_fn=<SelectBackward0>)
