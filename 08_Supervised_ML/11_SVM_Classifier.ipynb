# %%
import pandas as pd
from sklearn import datasets

# %%
# Read dataset
df = datasets.load_iris(as_frame=True).frame
df.head(3)
# Out:
#    sepal length (cm)  sepal width (cm)  ...  petal width (cm)  target
# 0                5.1               3.5  ...               0.2       0
# 1                4.9               3.0  ...               0.2       0
# 2                4.7               3.2  ...               0.2       0
#
# [3 rows x 5 columns]

# %%
# Train-Test Split
from sklearn.model_selection import train_test_split

X = df.drop(columns=["target"])
y = df["target"]

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.3, random_state=42, stratify=y)

# %%
# Scaling
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# Model
from sklearn.svm import SVC

svc = SVC()
svc.fit(X_train_scaled, y_train)

y_pred = svc.predict(X_test_scaled)

# %%
# Evaluate
from sklearn.metrics import accuracy_score, classification_report

print("Accuracy Score:", accuracy_score(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy Score: 0.9333333333333333
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        35
#            1       0.91      0.89      0.90        35
#            2       0.89      0.91      0.90        35
#
#     accuracy                           0.93       105
#    macro avg       0.93      0.93      0.93       105
# weighted avg       0.93      0.93      0.93       105

# %% [markdown]
# #### Linear Kernel

# %%
# Model
svc = SVC(kernel="linear")
svc.fit(X_train_scaled, y_train)

# Predict
y_pred = svc.predict(X_test_scaled)

# Evaluate
print("Accuracy Score:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy Score: 0.9714285714285714

# %% [markdown]
# #### Polynomial Kernel

# %%
# Model
svc = SVC(kernel="poly")
svc.fit(X_train_scaled, y_train)

# Predict
y_pred = svc.predict(X_test_scaled)

# Evaluate
print("Accuracy Score:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy Score: 0.8761904761904762

# %% [markdown]
# #### Sigmoid Kernel

# %%
# Model
svc = SVC(kernel="sigmoid")
svc.fit(X_train_scaled, y_train)

# Predict
y_pred = svc.predict(X_test_scaled)

# Evaluate
print("Accuracy Score:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy Score: 0.9333333333333333

# %% [markdown]
# ### Hyperparameter Tunning (C-val)

# %%
c_vals = [1, 3, 5, 7, 9, 10]

for c in c_vals:
    # Model
    svc = SVC(C=c, kernel="linear")
    svc.fit(X_train_scaled, y_train)
    # Predict
    y_pred = svc.predict(X_test_scaled)
    # Evaluate
    print(f"Accuracy Score for (C={c}): {accuracy_score(y_test, y_pred)}")
# Out:
# Accuracy Score for (C=1): 0.9714285714285714
# Accuracy Score for (C=3): 0.9714285714285714
# Accuracy Score for (C=5): 0.9809523809523809
# Accuracy Score for (C=7): 0.9714285714285714
# Accuracy Score for (C=9): 0.9714285714285714
# Accuracy Score for (C=10): 0.9714285714285714
